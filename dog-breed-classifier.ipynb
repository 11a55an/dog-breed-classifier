# %% [markdown]
# # Dog Breed Classifier

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam

# %% [markdown]
# ## Importing Data

# %%
labels_all = pd.read_csv("dog_dataset/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# breed
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: count, dtype: int64

# %%
CLASS_NAMES = ['scottish_deerhound','maltese_dog','bernese_mountain_dog', 'afghan_hound', 'entlebucher']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id               breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec         maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44  scottish_deerhound
# 3     80  01ee3c7ff9bcaba9874183135877670e         entlebucher
# 4     88  021b5a49189665c0442c19b5b33e8cf1         entlebucher

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('dog_dataset/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 588/588 [00:04<00:00, 145.37it/s]
# Train Images shape:  (588, 224, 224, 3)  size: 88,510,464
# One-hot encoded output shape:  (588, 5)  size: 2,940

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 8)         0
#  g2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 162749 (635.74 KB)
# Trainable params: 162749 (635.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 55s 10s/step - loss: 5.4055 - accuracy: 0.2199 - val_loss: 5.3943 - val_accuracy: 0.1887
# Epoch 2/100
# 4/4 [==============================] - 43s 10s/step - loss: 5.3580 - accuracy: 0.2813 - val_loss: 5.3463 - val_accuracy: 0.1509
# Epoch 3/100
# 4/4 [==============================] - 43s 10s/step - loss: 5.3110 - accuracy: 0.2742 - val_loss: 5.3028 - val_accuracy: 0.1792
# Epoch 4/100
# 4/4 [==============================] - 42s 10s/step - loss: 5.2645 - accuracy: 0.2884 - val_loss: 5.2597 - val_accuracy: 0.1887
# Epoch 5/100
# 4/4 [==============================] - 40s 9s/step - loss: 5.2199 - accuracy: 0.3050 - val_loss: 5.2197 - val_accuracy: 0.2075
# Epoch 6/100
# 4/4 [==============================] - 41s 10s/step - loss: 5.1743 - accuracy: 0.3026 - val_loss: 5.1764 - val_accuracy: 0.1981
# Epoch 7/100
# 4/4 [==============================] - 41s 10s/step - loss: 5.1286 - accuracy: 0.3121 - val_loss: 5.1356 - val_accuracy: 0.2170
# Epoch 8/100
# 4/4 [==============================] - 40s 9s/step - loss: 5.0839 - accuracy: 0.3215 - val_loss: 5.0937 - val_accuracy: 0.2264
# Epoch 9/100
# 4/4 [==============================] - 44s 10s/step - loss: 5.0382 - accuracy: 0.3097 - val_loss: 5.0478 - val_accuracy: 0.2075
# Epoch 10/100
# 4/4 [==============================] - 42s 10s/step - loss: 4.9935 - accuracy: 0.3215 - val_loss: 5.0017 - val_accuracy: 0.2170
# Epoch 11/100
# 4/4 [==============================] - 40s 10s/step - loss: 4.9468 - accuracy: 0.3333 - val_loss: 4.9595 - val_accuracy: 0.3019
# Epoch 12/100
# 4/4 [==============================] - 40s 10s/step - loss: 4.8985 - accuracy: 0.3570 - val_loss: 4.9223 - val_accuracy: 0.3208
# Epoch 13/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.8473 - accuracy: 0.3948 - val_loss: 4.8696 - val_accuracy: 0.3396
# Epoch 14/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.7976 - accuracy: 0.3381 - val_loss: 4.8117 - val_accuracy: 0.3679
# Epoch 15/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.7435 - accuracy: 0.3948 - val_loss: 4.7518 - val_accuracy: 0.3774
# Epoch 16/100
# 4/4 [==============================] - 41s 10s/step - loss: 4.6950 - accuracy: 0.4113 - val_loss: 4.7063 - val_accuracy: 0.3962
# Epoch 17/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.6413 - accuracy: 0.4113 - val_loss: 4.6930 - val_accuracy: 0.3585
# Epoch 18/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.5933 - accuracy: 0.4019 - val_loss: 4.6128 - val_accuracy: 0.4057
# Epoch 19/100
# 4/4 [==============================] - 41s 10s/step - loss: 4.5264 - accuracy: 0.4775 - val_loss: 4.5396 - val_accuracy: 0.5000
# Epoch 20/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.4786 - accuracy: 0.4681 - val_loss: 4.4954 - val_accuracy: 0.4340
# Epoch 21/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.4468 - accuracy: 0.4515 - val_loss: 4.4576 - val_accuracy: 0.4245
# Epoch 22/100
# 4/4 [==============================] - 40s 10s/step - loss: 4.3852 - accuracy: 0.4657 - val_loss: 4.3869 - val_accuracy: 0.5000
# Epoch 23/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.3394 - accuracy: 0.5248 - val_loss: 4.3463 - val_accuracy: 0.5283
# Epoch 24/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.2852 - accuracy: 0.5296 - val_loss: 4.3396 - val_accuracy: 0.4623
# Epoch 25/100
# 4/4 [==============================] - 41s 10s/step - loss: 4.2519 - accuracy: 0.5130 - val_loss: 4.2937 - val_accuracy: 0.5094
# Epoch 26/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.2120 - accuracy: 0.5106 - val_loss: 4.3405 - val_accuracy: 0.4057
# Epoch 27/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.2223 - accuracy: 0.4988 - val_loss: 4.2570 - val_accuracy: 0.4811
# Epoch 28/100
# 4/4 [==============================] - 41s 10s/step - loss: 4.1533 - accuracy: 0.5319 - val_loss: 4.2088 - val_accuracy: 0.5000
# Epoch 29/100
# 4/4 [==============================] - 40s 9s/step - loss: 4.1169 - accuracy: 0.5532 - val_loss: 4.1817 - val_accuracy: 0.4906
# Epoch 30/100
# 4/4 [==============================] - 39s 9s/step - loss: 4.0692 - accuracy: 0.5556 - val_loss: 4.1723 - val_accuracy: 0.4528
# Epoch 31/100
# 4/4 [==============================] - 46s 11s/step - loss: 4.0437 - accuracy: 0.5556 - val_loss: 4.0837 - val_accuracy: 0.5283
# Epoch 32/100
# 4/4 [==============================] - 45s 11s/step - loss: 4.0187 - accuracy: 0.5816 - val_loss: 4.1180 - val_accuracy: 0.5000
# Epoch 33/100
# 4/4 [==============================] - 42s 10s/step - loss: 4.0035 - accuracy: 0.5556 - val_loss: 4.1208 - val_accuracy: 0.4623
# Epoch 34/100
# 4/4 [==============================] - 37s 8s/step - loss: 3.9831 - accuracy: 0.5792 - val_loss: 4.0768 - val_accuracy: 0.5283
# Epoch 35/100
# 4/4 [==============================] - 40s 10s/step - loss: 3.9798 - accuracy: 0.5532 - val_loss: 4.0659 - val_accuracy: 0.5094
# Epoch 36/100
# 4/4 [==============================] - 36s 8s/step - loss: 3.9636 - accuracy: 0.6052 - val_loss: 3.9888 - val_accuracy: 0.5755
# Epoch 37/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.8866 - accuracy: 0.6217 - val_loss: 4.0520 - val_accuracy: 0.4717
# Epoch 38/100
# 4/4 [==============================] - 40s 9s/step - loss: 3.8422 - accuracy: 0.6217 - val_loss: 4.0167 - val_accuracy: 0.5094
# Epoch 39/100
# 4/4 [==============================] - 37s 9s/step - loss: 3.8439 - accuracy: 0.5910 - val_loss: 3.9629 - val_accuracy: 0.5472
# Epoch 40/100
# 4/4 [==============================] - 42s 10s/step - loss: 3.7855 - accuracy: 0.6548 - val_loss: 3.9866 - val_accuracy: 0.4906
# Epoch 41/100
# 4/4 [==============================] - 38s 9s/step - loss: 3.7919 - accuracy: 0.6265 - val_loss: 3.9448 - val_accuracy: 0.5566
# Epoch 42/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.7363 - accuracy: 0.6643 - val_loss: 4.0129 - val_accuracy: 0.5000
# Epoch 43/100
# 4/4 [==============================] - 37s 8s/step - loss: 3.7346 - accuracy: 0.6359 - val_loss: 3.9169 - val_accuracy: 0.5189
# Epoch 44/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.6756 - accuracy: 0.6903 - val_loss: 3.8917 - val_accuracy: 0.5283
# Epoch 45/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.6443 - accuracy: 0.6903 - val_loss: 3.9253 - val_accuracy: 0.4906
# Epoch 46/100
# 4/4 [==============================] - 36s 8s/step - loss: 3.6355 - accuracy: 0.6525 - val_loss: 3.8872 - val_accuracy: 0.5472
# Epoch 47/100
# 4/4 [==============================] - 36s 9s/step - loss: 3.6175 - accuracy: 0.6998 - val_loss: 3.8628 - val_accuracy: 0.5189
# Epoch 48/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.5739 - accuracy: 0.6879 - val_loss: 3.8849 - val_accuracy: 0.4623
# Epoch 49/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.5474 - accuracy: 0.7139 - val_loss: 3.8198 - val_accuracy: 0.5377
# Epoch 50/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.5150 - accuracy: 0.7234 - val_loss: 3.8616 - val_accuracy: 0.4717
# Epoch 51/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.4920 - accuracy: 0.7281 - val_loss: 3.8245 - val_accuracy: 0.5283
# Epoch 52/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.4836 - accuracy: 0.7329 - val_loss: 3.8755 - val_accuracy: 0.5000
# Epoch 53/100
# 4/4 [==============================] - 36s 8s/step - loss: 3.4565 - accuracy: 0.6974 - val_loss: 3.7960 - val_accuracy: 0.5755
# Epoch 54/100
# 4/4 [==============================] - 36s 8s/step - loss: 3.4311 - accuracy: 0.7258 - val_loss: 3.8514 - val_accuracy: 0.5000
# Epoch 55/100
# 4/4 [==============================] - 36s 8s/step - loss: 3.4183 - accuracy: 0.7281 - val_loss: 3.8455 - val_accuracy: 0.5283
# Epoch 56/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.4309 - accuracy: 0.7281 - val_loss: 3.9302 - val_accuracy: 0.5283
# Epoch 57/100
# 4/4 [==============================] - 37s 9s/step - loss: 3.4119 - accuracy: 0.7021 - val_loss: 3.8135 - val_accuracy: 0.5566
# Epoch 58/100
# 4/4 [==============================] - 38s 9s/step - loss: 3.4074 - accuracy: 0.7116 - val_loss: 3.7938 - val_accuracy: 0.5000
# Epoch 59/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.3481 - accuracy: 0.7423 - val_loss: 3.7908 - val_accuracy: 0.5377
# Epoch 60/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.3237 - accuracy: 0.7612 - val_loss: 3.8234 - val_accuracy: 0.5000
# Epoch 61/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.2814 - accuracy: 0.7636 - val_loss: 3.8239 - val_accuracy: 0.5000
# Epoch 62/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.2820 - accuracy: 0.7447 - val_loss: 3.8729 - val_accuracy: 0.5189
# Epoch 63/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.2763 - accuracy: 0.7636 - val_loss: 3.7750 - val_accuracy: 0.5377
# Epoch 64/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.2438 - accuracy: 0.7589 - val_loss: 3.7847 - val_accuracy: 0.4906
# Epoch 65/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.2463 - accuracy: 0.7494 - val_loss: 3.8452 - val_accuracy: 0.5189
# Epoch 66/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.2063 - accuracy: 0.7707 - val_loss: 3.7893 - val_accuracy: 0.5189
# Epoch 67/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.1842 - accuracy: 0.7707 - val_loss: 3.7872 - val_accuracy: 0.4906
# Epoch 68/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.1719 - accuracy: 0.7943 - val_loss: 3.7849 - val_accuracy: 0.4906
# Epoch 69/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.1670 - accuracy: 0.7825 - val_loss: 3.7920 - val_accuracy: 0.5094
# Epoch 70/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.1183 - accuracy: 0.8014 - val_loss: 3.7522 - val_accuracy: 0.5189
# Epoch 71/100
# 4/4 [==============================] - 34s 8s/step - loss: 3.1053 - accuracy: 0.8014 - val_loss: 3.7872 - val_accuracy: 0.4906
# Epoch 72/100
# 4/4 [==============================] - 36s 9s/step - loss: 3.0698 - accuracy: 0.8085 - val_loss: 3.7427 - val_accuracy: 0.5283
# Epoch 73/100
# 4/4 [==============================] - 37s 8s/step - loss: 3.0550 - accuracy: 0.8511 - val_loss: 3.8338 - val_accuracy: 0.4528
# Epoch 74/100
# 4/4 [==============================] - 35s 8s/step - loss: 3.0546 - accuracy: 0.8156 - val_loss: 3.7739 - val_accuracy: 0.5189
# Epoch 75/100
# 4/4 [==============================] - 33s 8s/step - loss: 3.0327 - accuracy: 0.8392 - val_loss: 3.8192 - val_accuracy: 0.4811
# Epoch 76/100
# 4/4 [==============================] - 32s 7s/step - loss: 3.0090 - accuracy: 0.8440 - val_loss: 3.7973 - val_accuracy: 0.5094
# Epoch 77/100
# 4/4 [==============================] - 35s 8s/step - loss: 2.9885 - accuracy: 0.8487 - val_loss: 3.7637 - val_accuracy: 0.4811
# Epoch 78/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.9666 - accuracy: 0.8534 - val_loss: 3.7752 - val_accuracy: 0.5377
# Epoch 79/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.9697 - accuracy: 0.8322 - val_loss: 3.8188 - val_accuracy: 0.5189
# Epoch 80/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.9630 - accuracy: 0.8416 - val_loss: 3.8888 - val_accuracy: 0.5189
# Epoch 81/100
# 4/4 [==============================] - 35s 8s/step - loss: 2.9538 - accuracy: 0.8392 - val_loss: 3.7881 - val_accuracy: 0.5377
# Epoch 82/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.9207 - accuracy: 0.8416 - val_loss: 3.8763 - val_accuracy: 0.5094
# Epoch 83/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.8885 - accuracy: 0.8605 - val_loss: 3.9076 - val_accuracy: 0.5189
# Epoch 84/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.9239 - accuracy: 0.8416 - val_loss: 3.8991 - val_accuracy: 0.5000
# Epoch 85/100
# 4/4 [==============================] - 36s 9s/step - loss: 2.9179 - accuracy: 0.8227 - val_loss: 3.8701 - val_accuracy: 0.5377
# Epoch 86/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.9149 - accuracy: 0.8487 - val_loss: 3.8691 - val_accuracy: 0.5189
# Epoch 87/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.8597 - accuracy: 0.8463 - val_loss: 3.8053 - val_accuracy: 0.5189
# Epoch 88/100
# 4/4 [==============================] - 44s 11s/step - loss: 2.8417 - accuracy: 0.8605 - val_loss: 3.8380 - val_accuracy: 0.5472
# Epoch 89/100
# 4/4 [==============================] - 35s 8s/step - loss: 2.8345 - accuracy: 0.8629 - val_loss: 3.8772 - val_accuracy: 0.5000
# Epoch 90/100
# 4/4 [==============================] - 36s 8s/step - loss: 2.8256 - accuracy: 0.8440 - val_loss: 3.8228 - val_accuracy: 0.5566
# Epoch 91/100
# 4/4 [==============================] - 35s 8s/step - loss: 2.8274 - accuracy: 0.8605 - val_loss: 3.9029 - val_accuracy: 0.5189
# Epoch 92/100
# 4/4 [==============================] - 35s 9s/step - loss: 2.8072 - accuracy: 0.8582 - val_loss: 3.8359 - val_accuracy: 0.5566
# Epoch 93/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.8030 - accuracy: 0.8605 - val_loss: 3.8730 - val_accuracy: 0.5000
# Epoch 94/100
# 4/4 [==============================] - 32s 8s/step - loss: 2.7282 - accuracy: 0.9007 - val_loss: 3.8172 - val_accuracy: 0.5094
# Epoch 95/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.7281 - accuracy: 0.9007 - val_loss: 3.9539 - val_accuracy: 0.5283
# Epoch 96/100
# 4/4 [==============================] - 35s 8s/step - loss: 2.7218 - accuracy: 0.8913 - val_loss: 3.8776 - val_accuracy: 0.5094
# Epoch 97/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.7206 - accuracy: 0.8818 - val_loss: 3.8681 - val_accuracy: 0.5189
# Epoch 98/100
# 4/4 [==============================] - 33s 8s/step - loss: 2.7291 - accuracy: 0.8700 - val_loss: 3.9907 - val_accuracy: 0.4811
# Epoch 99/100
# 4/4 [==============================] - 34s 8s/step - loss: 2.7270 - accuracy: 0.8889 - val_loss: 3.9090 - val_accuracy: 0.5094
# Epoch 100/100
# 4/4 [==============================] - 31s 7s/step - loss: 2.7087 - accuracy: 0.8889 - val_loss: 3.9644 - val_accuracy: 0.5094

# %%
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound
